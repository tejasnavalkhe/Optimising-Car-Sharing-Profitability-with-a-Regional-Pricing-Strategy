# %% [markdown]
# <a href="https://colab.research.google.com/github/tejasnavalkhe/Optimising-Car-Sharing-Profitability-with-a-Regional-Pricing-Strategy/blob/develop/code/Data%20Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 0. Load libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1. Load data

# %%
DATA_PATH = "/content/drive/MyDrive/MSc Dissertation/data/"

# %%
bookings_2019_df = pd.read_csv(f"{DATA_PATH}2019 Bookings.csv")
bookings_2020_df = pd.read_csv(f"{DATA_PATH}2020 Bookings.csv")
bookings_2021_df = pd.read_csv(f"{DATA_PATH}2021 Bookings.csv")
bookings_2022_df = pd.read_csv(f"{DATA_PATH}2022 Bookings.csv")
bookings_2023_df = pd.read_csv(f"{DATA_PATH}2023 Bookings.csv")
bookings_2024_df = pd.read_csv(f"{DATA_PATH}2024 Bookings.csv")
accounts_df = pd.read_csv(f"{DATA_PATH}accounts.csv")
users_df = pd.read_csv(f"{DATA_PATH}users.csv")
tariff_df = pd.read_csv(f"{DATA_PATH}Diff Tariffs.csv")
# Out:
# <ipython-input-26-7cab7aa5aa42>:1: DtypeWarning: Columns (37) have mixed types. Specify dtype option on import or set low_memory=False.
#   bookings_2019_df = pd.read_csv(f"{DATA_PATH}2019 Bookings.csv")
# <ipython-input-26-7cab7aa5aa42>:3: DtypeWarning: Columns (24,25,26,28,29,30,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   bookings_2021_df = pd.read_csv(f"{DATA_PATH}2021 Bookings.csv")
# <ipython-input-26-7cab7aa5aa42>:4: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   bookings_2022_df = pd.read_csv(f"{DATA_PATH}2022 Bookings.csv")
# <ipython-input-26-7cab7aa5aa42>:5: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   bookings_2023_df = pd.read_csv(f"{DATA_PATH}2023 Bookings.csv")
# <ipython-input-26-7cab7aa5aa42>:8: DtypeWarning: Columns (16,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   users_df = pd.read_csv(f"{DATA_PATH}users.csv")

# %%
bookings_df = pd.concat([bookings_2019_df, bookings_2020_df, bookings_2021_df, bookings_2022_df, bookings_2023_df, bookings_2024_df])

# %%
bookings_df.head()
# Out:
#                              account_id   Contract  \
# 0  9ef6f9f2-bb87-11e8-8478-3392d6ed7026       PAYG
# 1  837460ea-1a02-11ea-9ddd-919b17a2c51c       PAYG
# 2  bcdf83ac-cf78-11e9-a7b5-eba9440aff95       PAYG
# 3  10d4ff50-c68a-490b-9831-73a2a53a789e  Franchise
# 4  ad4720a8-371c-11e8-9c54-45ef183a979b   Contract
#
#                                 user_id  \
# 0  5cab890a-bb87-11e8-8c45-8b43f7434530
# 1  e4f9362e-1822-11ea-8de1-473e949dd300
# 2  5b58ca44-cf78-11e9-8a88-f32ff93f96dc
# 3  27a79ce4-eeff-4a45-9727-cff211058712
# 4  84845dc8-a7cb-11e8-a9fa-4fcddbe2d33e
#
#                                  vehicle_description vehicle_registration  \
# 0  RETIRED- White Toyota Yaris Hybrid NJ68 VOP Au...             NJ68 VOP
# 1  RETIRED - White Toyota Aygo X-Play Nav (NL66 NKZ)             NL66 NKZ
# 2                RETIRED - Renault Zoe EV (DL68 LNK)             DL68 LNK
# 3       RETIRED - Toyota Yaris Hybrid NAV (NJ18 VTX)             NJ18 VTX
# 4                RETIRED - SEAT Ateca 4X4 (NG18 EKY)             NG18 EKY
#
#    vehicle_communication_id vehicle_operator_name     vehicle_office_use  \
# 0                       NaN             Co-wheels                   PAYG
# 1                       NaN             Co-wheels                   PAYG
# 2                       NaN             Co-wheels                   PAYG
# 3                       NaN  Co-wheels Birmingham                   PAYG
# 4                       NaN             Co-wheels  Pool Car - Telematics
#
#                               location_description location_office_use  ...  \
# 0                                              NaN                 NaN  ...
# 1                                Lower Maudlin DNU                 NaN  ...
# 2                         Bristol - Effingham Road              BRI018  ...
# 3                                              NaN                 NaN  ...
# 4  North Shields - North Tyneside General Hospital              NTH006  ...
#
#   booking_actual_cost_time  booking_actual_cost_total booking_credits_used  \
# 0                      5.5                       8.38                    0
# 1                      9.5                      24.26                    0
# 2                     11.0                       11.0                    0
# 3                     38.5                      58.66                    0
# 4                      0.0                        0.0                    0
#
#   booking_transactions_value booking_total_paid  booking_status  \
# 0                      -8.38               8.38           ended
# 1                     -24.26              24.26           ended
# 2                     -11.00              11.00           ended
# 3                     -83.66               0.00           ended
# 4                       0.00               0.00           ended
#
#   booking_ended_early booking_created_at  booking_cancelled_at  \
# 0                  no   01/01/2020 23:30                   NaN
# 1                  no   01/01/2020 22:56                   NaN
# 2                  no   01/01/2020 22:36                   NaN
# 3                 yes   01/01/2020 22:53                   NaN
# 4                  no   12/30/2019 23:00                   NaN
#
#   booking_cancellation_reason
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 39 columns]

# %%
bookings_df.reset_index()
# Out:
#         index                            account_id   Contract  \
# 0           0  9ef6f9f2-bb87-11e8-8478-3392d6ed7026       PAYG
# 1           1  837460ea-1a02-11ea-9ddd-919b17a2c51c       PAYG
# 2           2  bcdf83ac-cf78-11e9-a7b5-eba9440aff95       PAYG
# 3           3  10d4ff50-c68a-490b-9831-73a2a53a789e  Franchise
# 4           4  ad4720a8-371c-11e8-9c54-45ef183a979b   Contract
# ...       ...                                   ...        ...
# 721188  53865  c816fa16-114e-11eb-b70a-7de30438bf3e       PAYG
# 721189  53866  1be16ad0-7528-11ec-a393-15f7512dc1c2   Contract
# 721190  53867  2093c091-cafa-4136-a474-597a230465ed       PAYG
# 721191  53868  7b9b8e00-5405-11e6-bedd-9b0e013041c9       PAYG
# 721192  53869  d50bebca-9c04-11ee-add9-0d432b57e15c       PAYG
#
#                                      user_id  \
# 0       5cab890a-bb87-11e8-8c45-8b43f7434530
# 1       e4f9362e-1822-11ea-8de1-473e949dd300
# 2       5b58ca44-cf78-11e9-8a88-f32ff93f96dc
# 3       27a79ce4-eeff-4a45-9727-cff211058712
# 4       84845dc8-a7cb-11e8-a9fa-4fcddbe2d33e
# ...                                      ...
# 721188  55c15e34-114e-11eb-9853-81bb51f48473
# 721189  9a356686-a12c-11ec-b4b4-8f51c3a3a3f1
# 721190  da59dcb5-5f44-424c-b0a8-2effb8cf9608
# 721191  25b18472-5405-11e6-8ab3-c1fe6b6a51e4
# 721192  8cc46f7c-9c04-11ee-b327-a3cde7999029
#
#                                       vehicle_description  \
# 0       RETIRED- White Toyota Yaris Hybrid NJ68 VOP Au...
# 1       RETIRED - White Toyota Aygo X-Play Nav (NL66 NKZ)
# 2                     RETIRED - Renault Zoe EV (DL68 LNK)
# 3            RETIRED - Toyota Yaris Hybrid NAV (NJ18 VTX)
# 4                     RETIRED - SEAT Ateca 4X4 (NG18 EKY)
# ...                                                   ...
# 721188              White MG 3 Petrol (Manual) - NG71 ZTF
# 721189  RETIRED - Black MG 3 (Manual) - Petrol - ND71 KPF
# 721190  White MG 4 Electric Vehicle (Automatic) - FL23...
# 721191              White MG 3 Petrol (Manual) - NC71 AAY
# 721192  White MG 4 Electric Vehicle (Automatic) - NL73...
#
#        vehicle_registration  vehicle_communication_id vehicle_operator_name  \
# 0                  NJ68 VOP                       NaN             Co-wheels
# 1                  NL66 NKZ                       NaN             Co-wheels
# 2                  DL68 LNK                       NaN             Co-wheels
# 3                  NJ18 VTX                       NaN  Co-wheels Birmingham
# 4                  NG18 EKY                       NaN             Co-wheels
# ...                     ...                       ...                   ...
# 721188             NG71 ZTF                    1929.0             Co-wheels
# 721189             ND71 KPF                    1729.0             Co-wheels
# 721190             FL23 HGM                    2045.0             Co-wheels
# 721191             NC71 AAY                    2287.0             Co-wheels
# 721192             NL73 HTG                    2214.0             Co-wheels
#
#            vehicle_office_use  \
# 0                        PAYG
# 1                        PAYG
# 2                        PAYG
# 3                        PAYG
# 4       Pool Car - Telematics
# ...                       ...
# 721188                   PAYG
# 721189   Pool Car - Exclusive
# 721190                   PAYG
# 721191          PAYG - Funded
# 721192                   PAYG
#
#                                    location_description  ...  \
# 0                                                   NaN  ...
# 1                                     Lower Maudlin DNU  ...
# 2                              Bristol - Effingham Road  ...
# 3                                                   NaN  ...
# 4       North Shields - North Tyneside General Hospital  ...
# ...                                                 ...  ...
# 721188             Tunbridge Wells - Goods Station Road  ...
# 721189           Llangefni - Plas Arthur Leisure Centre  ...
# 721190                     Eynsham - Back Lane Car Park  ...
# 721191                        Glasgow - Kilmarnock Road  ...
# 721192                        Dundee - South Tay Street  ...
#
#        booking_actual_cost_time booking_actual_cost_total  \
# 0                           5.5                      8.38
# 1                           9.5                     24.26
# 2                          11.0                      11.0
# 3                          38.5                     58.66
# 4                           0.0                       0.0
# ...                         ...                       ...
# 721188                     47.6                     81.04
# 721189                      0.0                       0.0
# 721190                     23.8                     28.12
# 721191                    12.94                     14.92
# 721192                    104.0                    123.24
#
#         booking_credits_used booking_transactions_value booking_total_paid  \
# 0                          0                      -8.38               8.38
# 1                          0                     -24.26              24.26
# 2                          0                     -11.00              11.00
# 3                          0                     -83.66               0.00
# 4                          0                       0.00               0.00
# ...                      ...                        ...                ...
# 721188                     0                     -81.04              81.04
# 721189                     0                       0.00               0.00
# 721190                     0                     -28.12               0.00
# 721191                     0                     -27.02              14.92
# 721192                     0                    -123.24             123.24
#
#        booking_status  booking_ended_early booking_created_at  \
# 0               ended                   no   01/01/2020 23:30
# 1               ended                   no   01/01/2020 22:56
# 2               ended                   no   01/01/2020 22:36
# 3               ended                  yes   01/01/2020 22:53
# 4               ended                   no   12/30/2019 23:00
# ...               ...                  ...                ...
# 721188          ended                   no    12/31/2023 1:13
# 721189          ended                   no   12/30/2023 19:39
# 721190          ended                   no    8/27/2023 12:48
# 721191          ended                   no   12/30/2023 16:45
# 721192          ended                   no    12/30/2023 9:54
#
#        booking_cancelled_at  booking_cancellation_reason
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
# ...                     ...                          ...
# 721188                  NaN                          NaN
# 721189                  NaN                          NaN
# 721190                  NaN                          NaN
# 721191                  NaN                          NaN
# 721192                  NaN                          NaN
#
# [721193 rows x 40 columns]

# %%
bookings_df.head()
# Out:
#                              account_id   Contract  \
# 0  9ef6f9f2-bb87-11e8-8478-3392d6ed7026       PAYG
# 1  837460ea-1a02-11ea-9ddd-919b17a2c51c       PAYG
# 2  bcdf83ac-cf78-11e9-a7b5-eba9440aff95       PAYG
# 3  10d4ff50-c68a-490b-9831-73a2a53a789e  Franchise
# 4  ad4720a8-371c-11e8-9c54-45ef183a979b   Contract
#
#                                 user_id  \
# 0  5cab890a-bb87-11e8-8c45-8b43f7434530
# 1  e4f9362e-1822-11ea-8de1-473e949dd300
# 2  5b58ca44-cf78-11e9-8a88-f32ff93f96dc
# 3  27a79ce4-eeff-4a45-9727-cff211058712
# 4  84845dc8-a7cb-11e8-a9fa-4fcddbe2d33e
#
#                                  vehicle_description vehicle_registration  \
# 0  RETIRED- White Toyota Yaris Hybrid NJ68 VOP Au...             NJ68 VOP
# 1  RETIRED - White Toyota Aygo X-Play Nav (NL66 NKZ)             NL66 NKZ
# 2                RETIRED - Renault Zoe EV (DL68 LNK)             DL68 LNK
# 3       RETIRED - Toyota Yaris Hybrid NAV (NJ18 VTX)             NJ18 VTX
# 4                RETIRED - SEAT Ateca 4X4 (NG18 EKY)             NG18 EKY
#
#    vehicle_communication_id vehicle_operator_name     vehicle_office_use  \
# 0                       NaN             Co-wheels                   PAYG
# 1                       NaN             Co-wheels                   PAYG
# 2                       NaN             Co-wheels                   PAYG
# 3                       NaN  Co-wheels Birmingham                   PAYG
# 4                       NaN             Co-wheels  Pool Car - Telematics
#
#                               location_description location_office_use  ...  \
# 0                                              NaN                 NaN  ...
# 1                                Lower Maudlin DNU                 NaN  ...
# 2                         Bristol - Effingham Road              BRI018  ...
# 3                                              NaN                 NaN  ...
# 4  North Shields - North Tyneside General Hospital              NTH006  ...
#
#   booking_actual_cost_time  booking_actual_cost_total booking_credits_used  \
# 0                      5.5                       8.38                    0
# 1                      9.5                      24.26                    0
# 2                     11.0                       11.0                    0
# 3                     38.5                      58.66                    0
# 4                      0.0                        0.0                    0
#
#   booking_transactions_value booking_total_paid  booking_status  \
# 0                      -8.38               8.38           ended
# 1                     -24.26              24.26           ended
# 2                     -11.00              11.00           ended
# 3                     -83.66               0.00           ended
# 4                       0.00               0.00           ended
#
#   booking_ended_early booking_created_at  booking_cancelled_at  \
# 0                  no   01/01/2020 23:30                   NaN
# 1                  no   01/01/2020 22:56                   NaN
# 2                  no   01/01/2020 22:36                   NaN
# 3                 yes   01/01/2020 22:53                   NaN
# 4                  no   12/30/2019 23:00                   NaN
#
#   booking_cancellation_reason
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ## 2. Data Cleaning

# %%
bookings_df.drop(['vehicle_registration', "vehicle_communication_id", "booking_id", "booking_reservation",
               "booking_maintenance", "booking_start", "booking_end", "booking_duration", "booking_rates_overnight",
               "booking_estimated_cost", "booking_credits_used", "booking_transactions_value", "booking_total_paid", "booking_status", "booking_ended_early",
               "booking_created_at", "booking_cancelled_at", "booking_cancellation_reason"], axis=1, inplace=True)

# %%
bookings_df.head()
# Out:
#                              account_id   Contract  \
# 0  9ef6f9f2-bb87-11e8-8478-3392d6ed7026       PAYG
# 1  837460ea-1a02-11ea-9ddd-919b17a2c51c       PAYG
# 2  bcdf83ac-cf78-11e9-a7b5-eba9440aff95       PAYG
# 3  10d4ff50-c68a-490b-9831-73a2a53a789e  Franchise
# 4  ad4720a8-371c-11e8-9c54-45ef183a979b   Contract
#
#                                 user_id  \
# 0  5cab890a-bb87-11e8-8c45-8b43f7434530
# 1  e4f9362e-1822-11ea-8de1-473e949dd300
# 2  5b58ca44-cf78-11e9-8a88-f32ff93f96dc
# 3  27a79ce4-eeff-4a45-9727-cff211058712
# 4  84845dc8-a7cb-11e8-a9fa-4fcddbe2d33e
#
#                                  vehicle_description vehicle_operator_name  \
# 0  RETIRED- White Toyota Yaris Hybrid NJ68 VOP Au...             Co-wheels
# 1  RETIRED - White Toyota Aygo X-Play Nav (NL66 NKZ)             Co-wheels
# 2                RETIRED - Renault Zoe EV (DL68 LNK)             Co-wheels
# 3       RETIRED - Toyota Yaris Hybrid NAV (NJ18 VTX)  Co-wheels Birmingham
# 4                RETIRED - SEAT Ateca 4X4 (NG18 EKY)             Co-wheels
#
#       vehicle_office_use                             location_description  \
# 0                   PAYG                                              NaN
# 1                   PAYG                                Lower Maudlin DNU
# 2                   PAYG                         Bristol - Effingham Road
# 3                   PAYG                                              NaN
# 4  Pool Car - Telematics  North Shields - North Tyneside General Hospital
#
#   location_office_use booking_actual_start booking_actual_end  ...  \
# 0                 NaN      01/02/2020 0:11    01/02/2020 0:35  ...
# 1                 NaN     01/01/2020 23:06    01/02/2020 1:24  ...
# 2              BRI018     01/01/2020 22:46    01/02/2020 2:01  ...
# 3                 NaN     01/01/2020 22:54   01/02/2020 22:30  ...
# 4              NTH006     01/01/2020 22:49    01/02/2020 8:29  ...
#
#    booking_billed_start booking_billed_end booking_billed_duration  \
# 0      01/01/2020 23:45    01/02/2020 0:45                      60
# 1      01/01/2020 23:00    01/02/2020 8:00                     540
# 2      01/01/2020 22:45    01/02/2020 2:30                     225
# 3      01/01/2020 22:45   01/02/2020 22:45                    1440
# 4      01/01/2020 22:30    01/02/2020 8:45                     615
#
#    booking_mileage                   booking_tariff booking_rates_hours  \
# 0             16.0        Co-wheels Standard Medium                 1.0
# 1             82.0         Co-wheels Standard Small                 0.0
# 2              5.0      Co-wheels Standard Electric                 0.0
# 3            112.0        Co-wheels Standard Medium                 0.0
# 4             40.0  Billing Exempt (24/7) (Default)               10.25
#
#   booking_rates_24hours booking_actual_cost_distance booking_actual_cost_time  \
# 0                     0                         2.88                      5.5
# 1                     0                        14.76                      9.5
# 2                     0                          0.0                     11.0
# 3                     1                        20.16                     38.5
# 4                     0                          0.0                      0.0
#
#   booking_actual_cost_total
# 0                      8.38
# 1                     24.26
# 2                      11.0
# 3                     58.66
# 4                       0.0
#
# [5 rows x 21 columns]

# %%
bookings_filtered_df = bookings_df[bookings_df['Contract'] == 'PAYG']

# %%
bookings_filtered_df.head()
# Out:
#                              account_id Contract  \
# 0  9ef6f9f2-bb87-11e8-8478-3392d6ed7026     PAYG
# 1  837460ea-1a02-11ea-9ddd-919b17a2c51c     PAYG
# 2  bcdf83ac-cf78-11e9-a7b5-eba9440aff95     PAYG
# 6  29f5ecce-4a9d-11e6-a70a-f39821a3496c     PAYG
# 7  68c151d8-0d0d-11ea-bed8-ebcb87cb5715     PAYG
#
#                                 user_id  \
# 0  5cab890a-bb87-11e8-8c45-8b43f7434530
# 1  e4f9362e-1822-11ea-8de1-473e949dd300
# 2  5b58ca44-cf78-11e9-8a88-f32ff93f96dc
# 6  622754ee-4a9c-11e6-a82f-4ba9e3c70859
# 7  efa7004a-0d0c-11ea-b0b4-590f743c744f
#
#                                  vehicle_description vehicle_operator_name  \
# 0  RETIRED- White Toyota Yaris Hybrid NJ68 VOP Au...             Co-wheels
# 1  RETIRED - White Toyota Aygo X-Play Nav (NL66 NKZ)             Co-wheels
# 2                RETIRED - Renault Zoe EV (DL68 LNK)             Co-wheels
# 6     RETIRED  - BMW i3 Electric Vehicle (Automatic)             Co-wheels
# 7  White Toyota Yaris Petrol Hybrid (Automatic) -...             Co-wheels
#
#   vehicle_office_use      location_description location_office_use  \
# 0               PAYG                       NaN                 NaN
# 1               PAYG         Lower Maudlin DNU                 NaN
# 2               PAYG  Bristol - Effingham Road              BRI018
# 6      PAYG - Funded                       NaN                 NaN
# 7      PAYG - Funded   Newbury - Boundary Road              NEW001
#
#   booking_actual_start booking_actual_end  ...  booking_billed_start  \
# 0      01/02/2020 0:11    01/02/2020 0:35  ...      01/01/2020 23:45
# 1     01/01/2020 23:06    01/02/2020 1:24  ...      01/01/2020 23:00
# 2     01/01/2020 22:46    01/02/2020 2:01  ...      01/01/2020 22:45
# 6     01/01/2020 22:22    01/02/2020 6:44  ...      01/01/2020 22:15
# 7     01/01/2020 21:29   01/01/2020 23:28  ...      01/01/2020 21:30
#
#   booking_billed_end booking_billed_duration  booking_mileage  \
# 0    01/02/2020 0:45                      60             16.0
# 1    01/02/2020 8:00                     540             82.0
# 2    01/02/2020 2:30                     225              5.0
# 6    01/02/2020 8:00                     585            113.0
# 7   01/01/2020 23:30                     120              6.0
#
#                 booking_tariff booking_rates_hours booking_rates_24hours  \
# 0    Co-wheels Standard Medium                 1.0                     0
# 1     Co-wheels Standard Small                 0.0                     0
# 2  Co-wheels Standard Electric                 0.0                     0
# 6  Co-wheels Standard Electric                 0.0                     0
# 7    Co-wheels Standard Medium                 2.0                     0
#
#   booking_actual_cost_distance booking_actual_cost_time  \
# 0                         2.88                      5.5
# 1                        14.76                      9.5
# 2                          0.0                     11.0
# 6                          0.0                     11.0
# 7                         1.08                     11.0
#
#   booking_actual_cost_total
# 0                      8.38
# 1                     24.26
# 2                      11.0
# 6                      11.0
# 7                     12.08
#
# [5 rows x 21 columns]

# %%
bookings_filtered_df = bookings_filtered_df[(bookings_filtered_df['vehicle_operator_name'] == 'Shropshire') | (bookings_filtered_df['vehicle_operator_name'] == 'Co-wheels')]

# %%
bookings_filtered_df.head()
# Out:
#                              account_id Contract  \
# 0  9ef6f9f2-bb87-11e8-8478-3392d6ed7026     PAYG
# 1  837460ea-1a02-11ea-9ddd-919b17a2c51c     PAYG
# 2  bcdf83ac-cf78-11e9-a7b5-eba9440aff95     PAYG
# 6  29f5ecce-4a9d-11e6-a70a-f39821a3496c     PAYG
# 7  68c151d8-0d0d-11ea-bed8-ebcb87cb5715     PAYG
#
#                                 user_id  \
# 0  5cab890a-bb87-11e8-8c45-8b43f7434530
# 1  e4f9362e-1822-11ea-8de1-473e949dd300
# 2  5b58ca44-cf78-11e9-8a88-f32ff93f96dc
# 6  622754ee-4a9c-11e6-a82f-4ba9e3c70859
# 7  efa7004a-0d0c-11ea-b0b4-590f743c744f
#
#                                  vehicle_description vehicle_operator_name  \
# 0  RETIRED- White Toyota Yaris Hybrid NJ68 VOP Au...             Co-wheels
# 1  RETIRED - White Toyota Aygo X-Play Nav (NL66 NKZ)             Co-wheels
# 2                RETIRED - Renault Zoe EV (DL68 LNK)             Co-wheels
# 6     RETIRED  - BMW i3 Electric Vehicle (Automatic)             Co-wheels
# 7  White Toyota Yaris Petrol Hybrid (Automatic) -...             Co-wheels
#
#   vehicle_office_use      location_description location_office_use  \
# 0               PAYG                       NaN                 NaN
# 1               PAYG         Lower Maudlin DNU                 NaN
# 2               PAYG  Bristol - Effingham Road              BRI018
# 6      PAYG - Funded                       NaN                 NaN
# 7      PAYG - Funded   Newbury - Boundary Road              NEW001
#
#   booking_actual_start booking_actual_end  ...  booking_billed_start  \
# 0      01/02/2020 0:11    01/02/2020 0:35  ...      01/01/2020 23:45
# 1     01/01/2020 23:06    01/02/2020 1:24  ...      01/01/2020 23:00
# 2     01/01/2020 22:46    01/02/2020 2:01  ...      01/01/2020 22:45
# 6     01/01/2020 22:22    01/02/2020 6:44  ...      01/01/2020 22:15
# 7     01/01/2020 21:29   01/01/2020 23:28  ...      01/01/2020 21:30
#
#   booking_billed_end booking_billed_duration  booking_mileage  \
# 0    01/02/2020 0:45                      60             16.0
# 1    01/02/2020 8:00                     540             82.0
# 2    01/02/2020 2:30                     225              5.0
# 6    01/02/2020 8:00                     585            113.0
# 7   01/01/2020 23:30                     120              6.0
#
#                 booking_tariff booking_rates_hours booking_rates_24hours  \
# 0    Co-wheels Standard Medium                 1.0                     0
# 1     Co-wheels Standard Small                 0.0                     0
# 2  Co-wheels Standard Electric                 0.0                     0
# 6  Co-wheels Standard Electric                 0.0                     0
# 7    Co-wheels Standard Medium                 2.0                     0
#
#   booking_actual_cost_distance booking_actual_cost_time  \
# 0                         2.88                      5.5
# 1                        14.76                      9.5
# 2                          0.0                     11.0
# 6                          0.0                     11.0
# 7                         1.08                     11.0
#
#   booking_actual_cost_total
# 0                      8.38
# 1                     24.26
# 2                      11.0
# 6                      11.0
# 7                     12.08
#
# [5 rows x 21 columns]

# %%
bookings_filtered_df.dropna(subset=['location_description', 'location_office_use'], how='all')
# Out:
#                                  account_id Contract  \
# 1      837460ea-1a02-11ea-9ddd-919b17a2c51c     PAYG
# 2      bcdf83ac-cf78-11e9-a7b5-eba9440aff95     PAYG
# 7      68c151d8-0d0d-11ea-bed8-ebcb87cb5715     PAYG
# 8      0fbf9512-b080-11e8-bea2-b13d9e3d63f4     PAYG
# 13     c47d6fd2-8a1f-11e9-895d-dfa9f573edde     PAYG
# ...                                     ...      ...
# 53863  02fb8f40-79a0-11ee-b8b7-793d73d6ed3a     PAYG
# 53865  c816fa16-114e-11eb-b70a-7de30438bf3e     PAYG
# 53867  2093c091-cafa-4136-a474-597a230465ed     PAYG
# 53868  7b9b8e00-5405-11e6-bedd-9b0e013041c9     PAYG
# 53869  d50bebca-9c04-11ee-add9-0d432b57e15c     PAYG
#
#                                     user_id  \
# 1      e4f9362e-1822-11ea-8de1-473e949dd300
# 2      5b58ca44-cf78-11e9-8a88-f32ff93f96dc
# 7      efa7004a-0d0c-11ea-b0b4-590f743c744f
# 8      afa8ac2e-b082-11e8-8af1-3bdb9d1130f9
# 13     f7bbebe0-7cd1-11e9-858f-1525255dc5c2
# ...                                     ...
# 53863  96862b36-799f-11ee-8678-29f8f91dee87
# 53865  55c15e34-114e-11eb-9853-81bb51f48473
# 53867  da59dcb5-5f44-424c-b0a8-2effb8cf9608
# 53868  25b18472-5405-11e6-8ab3-c1fe6b6a51e4
# 53869  8cc46f7c-9c04-11ee-b327-a3cde7999029
#
#                                      vehicle_description  \
# 1      RETIRED - White Toyota Aygo X-Play Nav (NL66 NKZ)
# 2                    RETIRED - Renault Zoe EV (DL68 LNK)
# 7      White Toyota Yaris Petrol Hybrid (Automatic) -...
# 8          RETIRED - White Toyota Aygo X-Play (NL68 JVP)
# 13     RETIRED - White Toyota Yaris Hybrid NJ68 JHV A...
# ...                                                  ...
# 53863    Green Hyundai i10 Petrol (Automatic) - BJ73 PWK
# 53865              White MG 3 Petrol (Manual) - NG71 ZTF
# 53867  White MG 4 Electric Vehicle (Automatic) - FL23...
# 53868              White MG 3 Petrol (Manual) - NC71 AAY
# 53869  White MG 4 Electric Vehicle (Automatic) - NL73...
#
#       vehicle_operator_name vehicle_office_use  \
# 1                 Co-wheels               PAYG
# 2                 Co-wheels               PAYG
# 7                 Co-wheels      PAYG - Funded
# 8                 Co-wheels               PAYG
# 13                Co-wheels               PAYG
# ...                     ...                ...
# 53863             Co-wheels               PAYG
# 53865             Co-wheels               PAYG
# 53867             Co-wheels               PAYG
# 53868             Co-wheels      PAYG - Funded
# 53869             Co-wheels               PAYG
#
#                        location_description location_office_use  \
# 1                         Lower Maudlin DNU                 NaN
# 2                  Bristol - Effingham Road              BRI018
# 7                   Newbury - Boundary Road              NEW001
# 8                  Swindon - Prospect Place              SWI002
# 13                   Horsham - North Street              HOR003
# ...                                     ...                 ...
# 53863                 Bristol - Church Lane              BRI013
# 53865  Tunbridge Wells - Goods Station Road              TUN008
# 53867          Eynsham - Back Lane Car Park              EYN001
# 53868             Glasgow - Kilmarnock Road              GLA042
# 53869             Dundee - South Tay Street              DDE012
#
#       booking_actual_start booking_actual_end  ...  booking_billed_start  \
# 1         01/01/2020 23:06    01/02/2020 1:24  ...      01/01/2020 23:00
# 2         01/01/2020 22:46    01/02/2020 2:01  ...      01/01/2020 22:45
# 7         01/01/2020 21:29   01/01/2020 23:28  ...      01/01/2020 21:30
# 8         01/01/2020 21:22   01/01/2020 21:38  ...      01/01/2020 21:15
# 13        01/01/2020 22:02   01/02/2020 19:50  ...      01/01/2020 20:30
# ...                    ...                ...  ...                   ...
# 53863      12/31/2023 6:27    01/03/2024 7:05  ...       12/31/2023 6:30
# 53865      12/31/2023 7:10   12/31/2023 17:59  ...       12/31/2023 6:15
# 53867      12/31/2023 5:45    12/31/2023 9:44  ...       12/31/2023 5:45
# 53868      12/31/2023 4:38    12/31/2023 5:05  ...       12/31/2023 3:30
# 53869     12/31/2023 14:59   01/01/2024 13:30  ...       12/31/2023 2:00
#
#       booking_billed_end booking_billed_duration  booking_mileage  \
# 1        01/02/2020 8:00                     540             82.0
# 2        01/02/2020 2:30                     225              5.0
# 7       01/01/2020 23:30                     120              6.0
# 8       01/01/2020 21:45                      30              6.0
# 13      01/02/2020 20:30                    1440             53.0
# ...                  ...                     ...              ...
# 53863    01/03/2024 7:30                    4380             62.0
# 53865   12/31/2023 19:15                     780            152.0
# 53867    12/31/2023 9:45                     240             36.0
# 53868    12/31/2023 5:45                     135              9.0
# 53869   01/01/2024 14:00                    2160            148.0
#
#                     booking_tariff booking_rates_hours booking_rates_24hours  \
# 1         Co-wheels Standard Small                 0.0                     0
# 2      Co-wheels Standard Electric                 0.0                     0
# 7        Co-wheels Standard Medium                 2.0                     0
# 8         Co-wheels Standard Small                 0.5                     0
# 13       Co-wheels Standard Medium                 0.0                     1
# ...                            ...                 ...                   ...
# 53863     Co-wheels Standard Small                 1.0                     3
# 53865     Tunbridge Wells Everyday                 0.0                     1
# 53867  Co-wheels Standard Electric                 4.0                     0
# 53868             Glasgow Everyday                2.25                     0
# 53869  Co-wheels Standard Electric                 0.0                     2
#
#       booking_actual_cost_distance booking_actual_cost_time  \
# 1                            14.76                      9.5
# 2                              0.0                     11.0
# 7                             1.08                     11.0
# 8                             1.08                     2.38
# 13                            9.54                     38.5
# ...                            ...                      ...
# 53863                        14.26                    137.5
# 53865                        33.44                     47.6
# 53867                         4.32                     23.8
# 53868                         1.98                    12.94
# 53869                        19.24                    104.0
#
#       booking_actual_cost_total
# 1                         24.26
# 2                          11.0
# 7                         12.08
# 8                          3.46
# 13                        48.04
# ...                         ...
# 53863                    151.76
# 53865                     81.04
# 53867                     28.12
# 53868                     14.92
# 53869                    123.24
#
# [379745 rows x 21 columns]

# %%
tariff_df
# Out:
#                                         Tariff Size Category Vehicle Type  \
# 0                              All Saints View        Medium     Everyday
# 1                           Bethesda Family EV         Large       Family
# 2   Billing Exempt (24/7) (Default, Co-wheels)       Various          NaN
# 3                          Caernarfon Electric         Large          NaN
# 4                          Canterbury Everyday        Medium     Everyday
# ..                                         ...           ...          ...
# 84    Dundee City Council Rates (non-electric)        Medium          NaN
# 85                   Hartlepool Standard Small         Small          NaN
# 86                         McCarthy & Stone EV        Medium          NaN
# 87               Sunderland City Council Rates       Various          NaN
# 88              University of Sunderland Rates       Various          NaN
#
#    PAYG or Contract Petrol Or EV Notes
# 0              PAYG           EV   NaN
# 1         Franchise           EV   NaN
# 2          Contract      Various   NaN
# 3         Franchise           EV   NaN
# 4              PAYG       Petrol   NaN
# ..              ...          ...   ...
# 84         Contract       Petrol   NaN
# 85        Franchise       Petrol   NaN
# 86         Contract           EV   NaN
# 87         Contract      Various   NaN
# 88         Contract      Various   NaN
#
# [89 rows x 6 columns]

# %%
tariff_df = tariff_df.rename(columns={"Tariff": "booking_tariff"})

# %%
tariff_df.head()

# %%
dff = pd.merge(bookings_filtered_df, tariff_df, how='outer', on='booking_tariff')

# %%
dff.iloc[1]

# %%
dff.head(5)

# %%
# dff.to_excel(f'{DATA_PATH}/combined_file_outer.xlsx')

# %%
dff[dff.isna()]

# %%
dff.isna().sum()

# %%
bookings_filtered.isna().sum()
